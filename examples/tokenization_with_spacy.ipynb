# %%
# Import spaCy and load the pre-trained English model
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
# Define a simple string with punctuation and contractions
my_string = '"We\'re from TX. USA!"'
print(my_string)
# Out:
# "We're from TX. USA!"

# %%
# Process the string to create a Doc object
doc = nlp(my_string)

# %%
# Iterate through tokens in the simple Doc object
for token in doc:
    print(token)
# Out:
# "
# We
# 're
# from
# TX
# .
# USA
# !
# "

# %%
# Process a more complex string with URLs, emails, currency, and special characters
doc2 = nlp(
    "Dr. Smith's research (published in 2023) shows e-commerce reached $2.5 billion! Visit https://example.com or email: support@example.com. The CEO said, \"We're expanding into AI, blockchain, and IoT—it's cutting-edge.\""
)

# %%
# Iterate through tokens in the complex Doc object
for token in doc2:
    print(token)
# Out:
# Dr.
# Smith
# 's
# research
# (
# published
# in
# 2023
# )
# shows
# e
# -
# commerce
# reached
# $
# 2.5
# billion
# !
# Visit
# https://example.com
# or
# email
# :
# support@example.com
# .
# The
# CEO
# said
# ,
# "
# We
# 're
# expanding
# into
# AI
# ,
# blockchain
# ,
# and
# IoT
# —
# it
# 's
# cutting
# -
# edge
# .
# "

# %%
# Process another complex string and print tokens in a single line with separators
doc3 = nlp("Apple Inc.'s Q3 2023 earnings—up 15% - were announced on Oct. 30th.")

# Iterate through tokens and print them on one line

for token in doc3:
    print(token, end=" | ")
# Out:
# Apple | Inc. | 's | Q3 | 2023 | earnings | — | up | 15 | % | - | were | announced | on | Oct. | 30th | . |

# %%
# Extract and display named entities (ORG, DATE, PERCENT, etc.) from doc3
for entity in doc3.ents:
    print(f"Entity: {entity}, Label: {entity.label_}")
    print(f"Explain: {str(spacy.explain(entity.label_))}\n")
# Out:
# Entity: Apple Inc.'s, Label: ORG
# Explain: Companies, agencies, institutions, etc.
#
# Entity: Q3 2023, Label: DATE
# Explain: Absolute or relative dates or periods
#
# Entity: 15%, Label: PERCENT
# Explain: Percentage, including "%"
#
# Entity: Oct. 30th, Label: DATE
# Explain: Absolute or relative dates or periods

# %%
# Extract and display noun chunks (phrases with a noun head) from doc3
for chunk in doc3.noun_chunks:
    print(chunk)
# Out:
# Apple Inc.'s Q3 2023 earnings
# Oct. 30th

# %%
# Import displacy for visualizing dependency and entity relationships
from spacy import displacy

# %%
# Create a Doc object from a short text and visualize dependency relationships
doc4 = nlp("Tesla's stock rose 12% today!")
displacy.render(doc4, style="dep", jupyter=True, options={"distance": 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9075f6f855d84cfe8a0c4bf1660921ef-0" class="displacy" width="650" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tesla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">stock</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">rose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">12%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">today!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-0" stroke-width="2px" d="M70,102.0 C70,2.0 250.0,2.0 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,104.0 L62,92.0 78,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-1" stroke-width="2px" d="M70,102.0 C70,52.0 145.0,52.0 145.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M145.0,104.0 L153.0,92.0 137.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-2" stroke-width="2px" d="M270,102.0 C270,52.0 345.0,52.0 345.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,104.0 L262,92.0 278,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-3" stroke-width="2px" d="M370,102.0 C370,52.0 445.0,52.0 445.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,104.0 L453.0,92.0 437.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-4" stroke-width="2px" d="M370,102.0 C370,2.0 550.0,2.0 550.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9075f6f855d84cfe8a0c4bf1660921ef-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550.0,104.0 L558.0,92.0 542.0,92.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Visualize named entities in doc4
displacy.render(doc4, style="ent", jupyter=True, options={"distance": 100})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's stock rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !</div></span>
